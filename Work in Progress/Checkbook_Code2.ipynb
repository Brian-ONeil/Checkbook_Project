# %%
import os
class Bank:
    def __init__(self):
        self.name = ''
        self.balance_file = 'balance.txt'
        self.load_balance()
    def welcome(self):
        self.name = input('Welcome to your terminal checkbook! Please enter your name: ')
    def print_current_balance(self):
        print('Your current balance is: {:.2f}'.format(self.total_amount))
    def deposit(self):
        amount = float(input('Hello {}, please enter the amount to deposit: '.format(self.name)))
        self.total_amount += amount
        self.save_balance()
        self.print_current_balance()
    def withdraw(self):
        amount = float(input('Hello {}, please enter the amount to withdraw: '.format(self.name)))
        if amount > self.total_amount:
            print('Insufficient balance!!')
        else:
            self.total_amount -= amount
            self.save_balance()
            self.print_current_balance()
    def load_balance(self):
        if os.path.isfile(self.balance_file):
            with open(self.balance_file, 'r') as f:
                self.total_amount = float(f.read().strip())
        else:
            self.total_amount = 0.00
    def save_balance(self):
        with open(self.balance_file, 'w') as f:
            f.write('{:.2f}'.format(self.total_amount))
if __name__ == "__main__":
    bank = Bank()
    bank.welcome()
    while True:
        input_value = int(input('What would you like to do?\n1. View your current balance\n2. Record a credit (deposit)\n3. Record a debit (withdraw)\n4. Exit\n'))
        if input_value == 1:
            bank.print_current_balance()
        elif input_value == 2:
            bank.deposit()
        elif input_value == 3:
            bank.withdraw()
        elif input_value == 4:
            print('Thank you for using your terminal checkbook!')
            break
        else:
            print('Invalid choice')

# %%
class Bank:
	def __init__(self):
		self.total_amount = 0.00       
		self.name = ''
        
	def welcome(self):
		self.name = input('Welcome to your terminal checkbook! Please Enter your name : ')
               
	def print_current_balance(self):
		print('Your Current balance is: {}'.format(self.total_amount))
                   
	def deposit(self):
		self.total_amount += float(input('Hello {}, please enter amount to deposit : '.format(self.name)))
		self.print_current_balance()

	def withdraw(self):
		amount_to_withdraw = float(input('Enter amount to withdraw : '))

		if amount_to_withdraw > self.total_amount:
			print('Insufficient balance !!')
		else:
			self.total_amount -= amount_to_withdraw

		self.print_current_balance()


if __name__=="__main__":
	bank = Bank()
	bank.welcome()

	while True:
		input_value = int(input('What would you like to do?\n1 view your current balance\n2 record a credit (deposit)\n3 record a debit (withdraw)\n4 to exit'))

		if input_value == 1:
			bank.print_current_balance()
		elif input_value == 2:
			bank.deposit()
		elif input_value == 3:
			bank.withdraw()
		elif input_value == 4:            
			print("Bye")           
			break            
		else:
			print('Invalid choice')
# Out:
# Welcome to your terminal checkbook! Please Enter your name : Brian
# What would you like to do?
# 1 view your current balance
# 2 record a credit (deposit)
# 3 record a debit (withdraw)
# 4 to exit1
# Your Current balance is: 0.0
# What would you like to do?
# 1 view your current balance
# 2 record a credit (deposit)
# 3 record a debit (withdraw)
# 4 to exit2
# Hello Brian, please enter amount to deposit : 200
# Your Current balance is: 200.0
# What would you like to do?
# 1 view your current balance
# 2 record a credit (deposit)
# 3 record a debit (withdraw)
# 4 to exit3
# Enter amount to withdraw : 3.55
# Your Current balance is: 196.45
# What would you like to do?
# 1 view your current balance
# 2 record a credit (deposit)
# 3 record a debit (withdraw)
# 4 to exit4
# Bye

# %%
		with open('checkbook_file.txt', 'w') as f:
			f.write(self.total_amount)

# %%
		with open('checkbook_file.txt') as f:
			self.total_amount = f.read()

# %%
class Bank:
    def __init__(self):
        self.total_amount = 0.00
        self.name = ''

    def welcome(self):
        self.name = input('Welcome to your terminal checkbook! Please Enter your name : ')

    def print_current_balance(self):
        print('Your Current balance is: {}'.format(self.total_amount))
    
    def deposit(self):
        self.total_amount += float(input('Hello {}, please enter amount to deposit : '.format(self.name)))
        self.print_current_balance()

    def withdraw(self):
        amount_to_withdraw = float(input('Enter amount to withdraw : '))

        if amount_to_withdraw > self.total_amount:
            print('Insufficient balance !!')
        else:
            self.total_amount -= amount_to_withdraw

        self.print_current_balance()


if __name__=="__main__":
    bank = Bank()
    bank.welcome()

    while True:
        input_value = int(input('What would you like to do?\n1 view your current balance\n2 record a credit (deposit)\n3 record a debit (withdraw)\n4 to exit'))

        if input_value == 1:
            bank.print_current_balance()
        elif input_value == 2:
            bank.deposit()
        elif input_value == 3:
            bank.withdraw()
        elif input_value == 4:
            print("Bye")
            break            
        else:
            print('Invalid choice')
# Out:
# Welcome to your terminal checkbook! Please Enter your name : Brian
# What would you like to do?
# 1 view your current balance
# 2 record a credit (deposit)
# 3 record a debit (withdraw)
# 4 to exit1
# Your Current balance is: 0.0
# What would you like to do?
# 1 view your current balance
# 2 record a credit (deposit)
# 3 record a debit (withdraw)
# 4 to exit200
# Invalid choice
# What would you like to do?
# 1 view your current balance
# 2 record a credit (deposit)
# 3 record a debit (withdraw)
# 4 to exit2
# Hello Brian, please enter amount to deposit : 200
# Your Current balance is: 200.0
# What would you like to do?
# 1 view your current balance
# 2 record a credit (deposit)
# 3 record a debit (withdraw)
# 4 to exit2.00
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [1], in <cell line: 27>()
#      29 bank.welcome()
#      31 while True:
# ---> 32     input_value = int(input('What would you like to do?\n1 view your current balance\n2 record a credit (deposit)\n3 record a debit (withdraw)\n4 to exit'))
#      34     if input_value == 1:
#      35         bank.print_current_balance()
#
# ValueError: invalid literal for int() with base 10: '2.00'

# %%
class Bank:
	def __init__(self):
		self.total_amount = 0.00       
		self.name = ''
		with open('checkbook_file.txt') as f:
			self.total_amount = f.read()        
	def welcome(self):
		self.name = input('Welcome to your terminal checkbook! Please Enter your name : ')
               
	def print_current_balance(self):
		print('Your Current balance is: {}'.format(self.total_amount))
                   
	def deposit(self):
		self.total_amount += float(input('Hello {}, please enter amount to deposit : '.format(self.name)))
		self.print_current_balance()

	def withdraw(self):
		amount_to_withdraw = float(input('Enter amount to withdraw : '))

		if amount_to_withdraw > self.total_amount:
			print('Insufficient balance !!')
		else:
			self.total_amount -= amount_to_withdraw

		self.print_current_balance()


if __name__=="__main__":
	bank = Bank()
	bank.welcome()

	while True:
		input_value = int(input('What would you like to do?\n1 view your current balance\n2 record a credit (deposit)\n3 record a debit (withdraw)\n4 to exit'))

		if input_value == 1:
			bank.print_current_balance()
		elif input_value == 2:
			bank.deposit()
		elif input_value == 3:
			bank.withdraw()
		elif input_value == 4:
			with open('checkbook_file.txt', 'w') as f:
				f.write(self.total_amount)            
			print("Bye")           
			break            
		else:
			print('Invalid choice')
# Out:
# Welcome to your terminal checkbook! Please Enter your name : Brian
# What would you like to do?
# 1 view your current balance
# 2 record a credit (deposit)
# 3 record a debit (withdraw)
# 4 to exit1
# Your Current balance is:
# What would you like to do?
# 1 view your current balance
# 2 record a credit (deposit)
# 3 record a debit (withdraw)
# 4 to exit1
# Your Current balance is:
# What would you like to do?
# 1 view your current balance
# 2 record a credit (deposit)
# 3 record a debit (withdraw)
# 4 to exit2
# Hello Brian, please enter amount to deposit : 200
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [3], in <cell line: 28>()
#      36 	bank.print_current_balance()
#      37 elif input_value == 2:
# ---> 38 	bank.deposit()
#      39 elif input_value == 3:
#      40 	bank.withdraw()
#
# Input In [3], in Bank.deposit(self)
#      13 def deposit(self):
# ---> 14 	self.total_amount += float(input('Hello {}, please enter amount to deposit : '.format(self.name)))
#      15 	self.print_current_balance()
#
# TypeError: can only concatenate str (not "float") to str

# %%
class Bank:
    def __init__(self):
        self.total_amount = 0.00       
        self.name = ''
        try:
            with open('checkbook_file.txt', 'r') as f:
                self.total_amount = float(f.read())        
        except FileNotFoundError:
            pass
          
    def welcome(self):
        self.name = input('Welcome to your terminal checkbook! Please Enter your name : ')
               
    def print_current_balance(self):
        print('Your Current balance is: {}'.format(self.total_amount))
                   
    def deposit(self):
        deposit_amount = float(input('Hello {}, please enter amount to deposit : '.format(self.name)))
        self.total_amount += deposit_amount
        self.print_current_balance()
    def withdraw(self):
        amount_to_withdraw = float(input('Enter amount to withdraw : '))
        if amount_to_withdraw > self.total_amount:
            print('Insufficient balance !!')
        else:
            self.total_amount -= amount_to_withdraw
        self.print_current_balance()
if __name__=="__main__":
    bank = Bank()
    bank.welcome()
    while True:
        input_value = input('What would you like to do?\n1 view your current balance\n2 record a credit (deposit)\n3 record a debit (withdraw)\n4 to exit\n')
        if input_value == '1':
            bank.print_current_balance()
        elif input_value == '2':
            bank.deposit()
        elif input_value == '3':
            bank.withdraw()
        elif input_value == '4':
            with open('checkbook_file.txt', 'w') as f:
                f.write(str(bank.total_amount))            
            print("Bye")           
            break            
        else:
            print('Invalid choice')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [1], in <cell line: 28>()
#      27         self.print_current_balance()
#      28 if __name__=="__main__":
# ---> 29     bank = Bank()
#      30     bank.welcome()
#      31     while True:
#
# Input In [1], in Bank.__init__(self)
#       5 try:
#       6     with open('checkbook_file.txt', 'r') as f:
# ----> 7         self.total_amount = float(f.read())
#       8 except FileNotFoundError:
#       9     pass
#
# ValueError: could not convert string to float: ''

# %%
class Bank:
    def __init__(self):
        self.total_amount = 0.00       
        self.name = ''
        try:
            with open('checkbook_file.txt', 'r') as f:
                self.total_amount = str(f.read())        
        except FileNotFoundError:
            pass
          
    def welcome(self):
        self.name = input('Welcome to your terminal checkbook! Please Enter your name : ')
               
    def print_current_balance(self):
        print('Your Current balance is: {}'.format(self.total_amount))
                   
    def deposit(self):
        deposit_amount = float(input('Hello {}, please enter amount to deposit : '.format(self.name)))
        self.total_amount += deposit_amount
        self.print_current_balance()
        
    def withdraw(self):
        amount_to_withdraw = float(input('Enter amount to withdraw : '))
        if amount_to_withdraw > self.total_amount:
            print('Insufficient balance !!')
        else:
            self.total_amount -= amount_to_withdraw
            self.print_current_balance()
        
if __name__=="__main__":
    bank = Bank()
    bank.welcome()
    while True:
        input_value = input('What would you like to do?\n1. View your current balance\n2. Record a credit (deposit)\n3. Record a debit (withdraw)\n4. Exit\n')
        if input_value == '1':
            bank.print_current_balance()
        elif input_value == '2':
            bank.deposit()
        elif input_value == '3':
            bank.withdraw()
        elif input_value == '4':
            with open('checkbook_file.txt', 'w') as f:
                f.write(float(bank.total_amount))            
            print("Bye")
            break
        else:
            print('Invalid choice')
# Out:
# Welcome to your terminal checkbook! Please Enter your name : Brian
# What would you like to do?
# 1. View your current balance
# 2. Record a credit (deposit)
# 3. Record a debit (withdraw)
# 4. Exit
# 3
# Enter amount to withdraw : 200
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [3], in <cell line: 30>()
#      38     bank.deposit()
#      39 elif input_value == '3':
# ---> 40     bank.withdraw()
#      41 elif input_value == '4':
#      42     with open('checkbook_file.txt', 'w') as f:
#
# Input In [3], in Bank.withdraw(self)
#      22 def withdraw(self):
#      23     amount_to_withdraw = float(input('Enter amount to withdraw : '))
# ---> 24     if amount_to_withdraw > self.total_amount:
#      25         print('Insufficient balance !!')
#      26     else:
#
# TypeError: '>' not supported between instances of 'float' and 'str'

# %%
class Bank:
    def __init__(self):
        self.total_amount = 0.00
        self.name = ''
        
    def welcome(self):
        self.name = input('Welcome to your terminal checkbook! Please Enter your name : ')
               
    def print_current_balance(self):
        print('Your Current balance is: {}'.format(self.total_amount))
                   
    def deposit(self):
        deposit_amount = float(input('Hello {}, please enter amount to deposit : '.format(self.name)))
        self.total_amount += deposit_amount
        self.print_current_balance()
        with open('transaction_history.txt', 'a') as f:
            f.write('Deposit of amount {} on {}\n'.format(deposit_amount, get_current_time()))
        
    def withdraw(self):
        amount_to_withdraw = float(input('Enter amount to withdraw : '))
        if amount_to_withdraw > self.total_amount:
            print('Insufficient balance !!')
        else:
            self.total_amount -= amount_to_withdraw
            self.print_current_balance()
            with open('transaction_history.txt', 'a') as f:
                f.write('Withdrawal of amount {} on {}\n'.format(amount_to_withdraw, get_current_time()))
def get_current_time():
    import datetime
    return datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")
if __name__=="__main__":
    bank = Bank()
    bank.welcome()
    while True:
        input_value = int(input('What would you like to do?\n1 view your current balance\n2 record a credit (deposit)\n3 record a debit (withdraw)\n4 to exit'))
        if input_value == 1:
            bank.print_current_balance()
        elif input_value == 2:
            bank.deposit()
        elif input_value == 3:
            bank.withdraw()
        elif input_value == 4:
            print("Bye")
            break
        else:
            print('Invalid choice')
# Out:
# Welcome to your terminal checkbook! Please Enter your name : Brian
# What would you like to do?
# 1 view your current balance
# 2 record a credit (deposit)
# 3 record a debit (withdraw)
# 4 to exit1
# Your Current balance is: 0.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [5], in <cell line: 31>()
#      33 bank.welcome()
#      34 while True:
# ---> 35     input_value = int(input('What would you like to do?\n1 view your current balance\n2 record a credit (deposit)\n3 record a debit (withdraw)\n4 to exit'))
#      36     if input_value == 1:
#      37         bank.print_current_balance()
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/ipykernel/kernelbase.py:1177, in Kernel.raw_input(self, prompt)
#    1173 if not self._allow_stdin:
#    1174     raise StdinNotImplementedError(
#    1175         "raw_input was called, but this frontend does not support input requests."
#    1176     )
# -> 1177 return self._input_request(
#    1178     str(prompt),
#    1179     self._parent_ident["shell"],
#    1180     self.get_parent("shell"),
#    1181     password=False,
#    1182 )
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/ipykernel/kernelbase.py:1219, in Kernel._input_request(self, prompt, ident, parent, password)
#    1216             break
#    1217 except KeyboardInterrupt:
#    1218     # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219     raise KeyboardInterrupt("Interrupted by user") from None
#    1220 except Exception:
#    1221     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
import os
class Bank:
    def __init__(self):
        self.name = ''
        self.balance_file = 'balance.txt'
        self.load_balance()
    def welcome(self):
        self.name = input('Welcome to your terminal checkbook! Please enter your name: ')
    def print_current_balance(self):
        print('Your current balance is: {:.2f}'.format(self.total_amount))
    def deposit(self):
        amount = float(input('Hello {}, please enter the amount to deposit: '.format(self.name)))
        self.total_amount += amount
        self.save_balance()
        self.print_current_balance()
    def withdraw(self):
        amount = float(input('Hello {}, please enter the amount to withdraw: '.format(self.name)))
        if amount > self.total_amount:
            print('Insufficient balance!!')
        else:
            self.total_amount -= amount
            self.save_balance()
            self.print_current_balance()
    def load_balance(self):
        if os.path.isfile(self.balance_file):
            with open(self.balance_file, 'r') as f:
                self.total_amount = float(f.read().strip())
        else:
            self.total_amount = 0.00
    def save_balance(self):
        with open(self.balance_file, 'w') as f:
            f.write('{:.2f}'.format(self.total_amount))
if __name__ == "__main__":
    bank = Bank()
    bank.welcome()
    while True:
        input_value = int(input('What would you like to do?\n1. View your current balance\n2. Record a credit (deposit)\n3. Record a debit (withdraw)\n4. Exit\n'))
        if input_value == 1:
            bank.print_current_balance()
        elif input_value == 2:
            bank.deposit()
        elif input_value == 3:
            bank.withdraw()
        elif input_value == 4:
            print('Thank you for using your terminal checkbook!')
            break
        else:
            print('Invalid choice')
# Out:
# Welcome to your terminal checkbook! Please enter your name: Brian
# What would you like to do?
# 1. View your current balance
# 2. Record a credit (deposit)
# 3. Record a debit (withdraw)
# 4. Exit
# 1
# Your current balance is: 196.45
# What would you like to do?
# 1. View your current balance
# 2. Record a credit (deposit)
# 3. Record a debit (withdraw)
# 4. Exit
# 5
# Invalid choice
# What would you like to do?
# 1. View your current balance
# 2. Record a credit (deposit)
# 3. Record a debit (withdraw)
# 4. Exit
# 2
# Hello Brian, please enter the amount to deposit: 3.555
# Your current balance is: 200.00
